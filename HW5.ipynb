# %% [markdown]
# <a href="https://colab.research.google.com/github/Miughe/Homework5/blob/master/HW5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install -U PySuperTuxKart
# !pip install -U Pillow
# !pip install -U future
# !pip install -U matplotlib
# !pip install -U numpy
# !pip install -U tensorboard>=1.14
# !pip install -U torch>=1.6.0
# !pip install -U torchvision>=0.7.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 39.1 MB/s eta 0:00:00
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for PySuperTuxKartData: filename=PySuperTuxKartData-1.0.0-py3-none-any.whl size=620700372 sha256=cef8eebe31ed8437b73f0c857b12f27c881cdae09925fd00639b84e7ed41232e
#   Stored in directory: /root/.cache/pip/wheels/5b/da/db/107e5e579034a950bc34417909d989352cd89aa65988af479f
# Successfully built PySuperTuxKartData
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 33.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# %cd /content/Homework5/homework5/
# Out:
# /content/Homework5/homework5

# %%
# !rm -rf Homework5
# !git clone https://github.com/Miughe/Homework5.git
# Out:
# Cloning into 'Homework5'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 31 (delta 0), reused 31 (delta 0), pack-reused 0
# Receiving objects: 100% (31/31), 14.57 KiB | 3.64 MiB/s, done.

# %%
# !python3 -m homework.controller hacienda -v
# Out:
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'homework.controller' found in sys.modules after import of package 'homework', but prior to execution of 'homework.controller'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# Figure(640x480)
# 1000 0.512775180576012

# %%
# !python3 -m homework.controller lighthouse -v
# Out:
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'homework.controller' found in sys.modules after import of package 'homework', but prior to execution of 'homework.controller'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# Figure(640x480)
# Finished at t=774
# 774 0.999069824486168

# %%
# !python3 -m homework.controller cornfield_crossing -v
# Out:
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'homework.controller' found in sys.modules after import of package 'homework', but prior to execution of 'homework.controller'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# Figure(640x480)
# Finished at t=895
# 895 0.9990382841528893

# %%
# !python3 -m homework.controller scotland -v
# Out:
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'homework.controller' found in sys.modules after import of package 'homework', but prior to execution of 'homework.controller'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# Figure(640x480)
# 1000 0.8992651320182529

# %%
# !python3 -m homework.controller zengarden -v
# Out:
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'homework.controller' found in sys.modules after import of package 'homework', but prior to execution of 'homework.controller'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# Figure(640x480)
# 1000 1.9990203749467208

# %%
# !python3 -m homework.controller snowtuxpeak -v
# Out:
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'homework.controller' found in sys.modules after import of package 'homework', but prior to execution of 'homework.controller'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# Figure(640x480)
# 1000 0.4469041385660985

# %%
# !python3 -m grader homework -v
# Out:
# Loading assignment
# Loading grader
#  * Controller
#   - cornfield_crossing                                 [ 68.6 s ]
#   - hacienda                                           [ 66.9 s ]
#   - lighthouse                                         [ 47.7 s ]
#   - scotland                                           [ 69.2 s ]
#   - snowtuxpeak                                        [ 60.9 s ]
#   - zengarden                                          [ 53.8 s ]
#  --------------------------------------------------    [  30 /  30 ]
#
#   - Function not implemented: Planner.__init__
#  --------------------------------------------------    [   0 /  60 ]
#
#   - Function not implemented: Planner.__init__
#  --------------------------------------------------    [   0 /  10 ]
#
#
# total score                                               30 / 100

# %%
# !sudo apt-get purge nvidia*
# !sudo add-apt-repository ppa:graphics-drivers/ppa -y
# !sudo apt-get update
# !sudo apt install nvidia-driver-530 nvidia-dkms-530 -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'nvidia-docker2' for glob 'nvidia*'
# Note, selecting 'nvidia-cuda-toolkit-doc' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-390' for glob 'nvidia*'
# Note, selecting 'nvidia-cuda-toolkit-gcc' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-418' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-430' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-435' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-440' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-450' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-455' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-460' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-465' for glob 'nvidia*'
# Note, selecting 'nvidia-headless-470' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-470-server' for glob 'nvidia*'
# ...

# %%
# !git config --global user.email "anthonydohogne7@gmail.com"
# !git config --global user.name "Miughe"

# %%
# !git add .

# %%
# !git commit -m "new code"
# Out:
# Streaming output truncated to the last 5000 lines.
#  create mode 100644 homework5/drive_data/snowtuxpeak_00832.png
#  create mode 100644 homework5/drive_data/snowtuxpeak_00833.csv
#  create mode 100644 homework5/drive_data/snowtuxpeak_00833.png
#  create mode 100644 homework5/drive_data/snowtuxpeak_00834.csv
#  create mode 100644 homework5/drive_data/snowtuxpeak_00834.png
#  create mode 100644 homework5/drive_data/snowtuxpeak_00835.csv
#  create mode 100644 homework5/drive_data/snowtuxpeak_00835.png
#  create mode 100644 homework5/drive_data/snowtuxpeak_00836.csv
#  create mode 100644 homework5/drive_data/snowtuxpeak_00836.png
#  create mode 100644 homework5/drive_data/snowtuxpeak_00837.csv
#  create mode 100644 homework5/drive_data/snowtuxpeak_00837.png
#  create mode 100644 homework5/drive_data/snowtuxpeak_00838.csv
#  create mode 100644 homework5/drive_data/snowtuxpeak_00838.png
#  create mode 100644 homework5/drive_data/snowtuxpeak_00839.csv
# ...

# %%
# !python3 -m homework.utils zengarden lighthouse hacienda snowtuxpeak cornfield_crossing scotland -v
# Out:
# Figure(640x480)
# 1000 1.9918686481062573
# Figure(640x480)
# Finished at t=532
# 532 0.9981399839696157
# Figure(640x480)
# Finished at t=575
# 575 1.000881507897443
# Figure(640x480)
# Finished at t=486
# 486 1.0
# Figure(640x480)
# 1000 1.9918686481062573
# Figure(640x480)
# Finished at t=560
# 560 0.9996686183274427
# Figure(640x480)
# Finished at t=539
# 539 0.9984166365456163
# Figure(640x480)
# Finished at t=445
# 445 0.999073385704296
# Figure(640x480)
# Finished at t=482
# 482 1.0006417996095418
# Figure(640x480)
# Finished at t=552
# 552 0.9987355602605587
# Figure(640x480)
# Finished at t=467
# 467 0.9993221152718494
# Figure(640x480)
# Finished at t=524
# 524 0.9988875473434609
# Figure(640x480)
# Finished at t=546
# 546 0.9980681574001944
# Figure(640x480)
# Finished at t=554
# 554 0.9981526137611287
# Figure(640x480)
# Finished at t=543
# 543 0.9998636498018283
# Figure(640x480)
# Finished at t=489
# 489 1.0007376829247023
# Figure(640x480)
# Finished at t=492
# ...

# %%
# !python3 -m homework.visualize_data drive_data
# Out:
# Figure(2000x400)
